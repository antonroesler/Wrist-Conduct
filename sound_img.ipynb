# %%
# %matplotlib inline
import sklearn
import matplotlib.pyplot as plt
import librosa.display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/anton/Programming/Python/Wrist Conduct/sound_img.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/Users/anton/Programming/Python/Wrist%20Conduct/sound_img.ipynb#ch0000000?line=0'>1</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/Users/anton/Programming/Python/Wrist%20Conduct/sound_img.ipynb#ch0000000?line=1'>2</a> import sklearn
#       <a href='vscode-notebook-cell:/Users/anton/Programming/Python/Wrist%20Conduct/sound_img.ipynb#ch0000000?line=2'>3</a> import matplotlib.pyplot as plt
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2204, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=2201'>2202</a>     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=2202'>2203</a> with self.builtin_trap:
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=2203'>2204</a>     result = fn(*args, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=2204'>2205</a> return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/magics/pylab.py:99, in PylabMagics.matplotlib(self, line)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/magics/pylab.py?line=96'>97</a>     print("Available matplotlib backends: %s" % backends_list)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/magics/pylab.py?line=97'>98</a> else:
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/magics/pylab.py?line=98'>99</a>     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/magics/pylab.py?line=99'>100</a>     self._show_matplotlib_backend(args.gui, backend)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3327, in InteractiveShell.enable_matplotlib(self, gui)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3305'>3306</a> """Enable interactive matplotlib and inline figure support.
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3306'>3307</a>
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3307'>3308</a> This takes the following steps:
#    (...)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3323'>3324</a>     display figures inline.
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3324'>3325</a> """
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3325'>3326</a> from IPython.core import pylabtools as pt
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3326'>3327</a> from matplotlib_inline.backend_inline import configure_inline_support
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3327'>3328</a> gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3329'>3330</a> if gui != 'inline':
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/IPython/core/interactiveshell.py?line=3330'>3331</a>     # If we have our first gui selection, store it
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:6, in <module>
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=0'>1</a> """A matplotlib backend for publishing figures via display_data"""
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=2'>3</a> # Copyright (c) IPython Development Team.
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=3'>4</a> # Distributed under the terms of the BSD 3-Clause License.
# ----> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=5'>6</a> import matplotlib
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=6'>7</a> from matplotlib.backends.backend_agg import (  # noqa
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=7'>8</a>     new_figure_manager,
#       <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=8'>9</a>     FigureCanvasAgg,
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=9'>10</a>     new_figure_manager_given_figure,
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=10'>11</a> )
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/wrist/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py?line=11'>12</a> from matplotlib import colors
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
x , sr = librosa.load(audio_path)
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniforge/base/envs/wrist
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     audioread-2.1.9            |  py310hbe9552e_2          34 KB  conda-forge
#     brotlipy-0.7.0             |py310he2143c4_1003         349 KB  conda-forge
#     charset-normalizer-2.0.11  |     pyhd8ed1ab_0          35 KB  conda-forge
#     cryptography-36.0.1        |  py310heb878e4_0         1.3 MB  conda-forge
#     ffmpeg-4.3.2               |       ha8417bf_1        46.6 MB  conda-forge
#     gnutls-3.6.13              |       h706517b_1         2.0 MB  conda-forge
#     idna-3.3                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     lame-3.100                 |    h27ca646_1001         516 KB  conda-forge
#     libflac-1.3.3              |       h9f76cd9_1         320 KB  conda-forge
#     libllvm11-11.1.0           |       h93073aa_2        20.9 MB  conda-forge
#     libogg-1.3.4               |       h27ca646_1         203 KB  conda-forge
#     libopus-1.3.1              |       h27ca646_1         247 KB  conda-forge
#     librosa-0.9.0              |     pyhd8ed1ab_0         153 KB  conda-forge
#     libsndfile-1.0.31          |       h9f76cd9_1         564 KB  conda-forge
#     libvorbis-1.3.7            |       h9f76cd9_0         249 KB  conda-forge
#     llvmlite-0.38.0            |  py310h1ef11ee_0         243 KB  conda-forge
#     nettle-3.6                 |       hc6a1b29_0         1.2 MB  conda-forge
#     numba-0.55.1               |  py310h30f798c_0         3.8 MB  conda-forge
#     numpy-1.21.5               |  py310h296e039_0         5.5 MB  conda-forge
#     openh264-2.1.1             |       habe5f53_0         1.3 MB  conda-forge
#     pooch-1.6.0                |     pyhd8ed1ab_0          44 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_0          49 KB  conda-forge
#     pysocks-1.7.1              |  py310hbe9552e_4          28 KB  conda-forge
#     pysoundfile-0.10.3.post1   |     pyhd3deb0d_0          23 KB  conda-forge
#     python-3.10.2              |h70c1b39_0_cpython        12.3 MB  conda-forge
#     requests-2.27.1            |     pyhd8ed1ab_0          53 KB  conda-forge
#     resampy-0.2.2              |             py_0         332 KB  conda-forge
#     scikit-learn-1.0.2         |  py310h5f111c3_0         7.3 MB  conda-forge
#     threadpoolctl-3.1.0        |     pyh8a188c0_0          18 KB  conda-forge
#     urllib3-1.26.8             |     pyhd8ed1ab_1         100 KB  conda-forge
#     x264-1!161.3030            |       h3422bc3_1         2.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       107.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   audioread          conda-forge/osx-arm64::audioread-2.1.9-py310hbe9552e_2
#   brotlipy           conda-forge/osx-arm64::brotlipy-0.7.0-py310he2143c4_1003
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.11-pyhd8ed1ab_0
#   cryptography       conda-forge/osx-arm64::cryptography-36.0.1-py310heb878e4_0
#   ffmpeg             conda-forge/osx-arm64::ffmpeg-4.3.2-ha8417bf_1
#   gettext            conda-forge/osx-arm64::gettext-0.19.8.1-h049c9fb_1008
#   gmp                conda-forge/osx-arm64::gmp-6.2.1-h9f76cd9_0
#   gnutls             conda-forge/osx-arm64::gnutls-3.6.13-h706517b_1
#   idna               conda-forge/noarch::idna-3.3-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.1.0-pyhd8ed1ab_0
#   lame               conda-forge/osx-arm64::lame-3.100-h27ca646_1001
#   libflac            conda-forge/osx-arm64::libflac-1.3.3-h9f76cd9_1
#   libiconv           conda-forge/osx-arm64::libiconv-1.16-h642e427_0
#   libllvm11          conda-forge/osx-arm64::libllvm11-11.1.0-h93073aa_2
#   libogg             conda-forge/osx-arm64::libogg-1.3.4-h27ca646_1
#   libopus            conda-forge/osx-arm64::libopus-1.3.1-h27ca646_1
#   librosa            conda-forge/noarch::librosa-0.9.0-pyhd8ed1ab_0
#   libsndfile         conda-forge/osx-arm64::libsndfile-1.0.31-h9f76cd9_1
#   libvorbis          conda-forge/osx-arm64::libvorbis-1.3.7-h9f76cd9_0
#   llvmlite           conda-forge/osx-arm64::llvmlite-0.38.0-py310h1ef11ee_0
#   nettle             conda-forge/osx-arm64::nettle-3.6-hc6a1b29_0
#   numba              conda-forge/osx-arm64::numba-0.55.1-py310h30f798c_0
#   openh264           conda-forge/osx-arm64::openh264-2.1.1-habe5f53_0
#   pooch              conda-forge/noarch::pooch-1.6.0-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-22.0.0-pyhd8ed1ab_0
#   pysocks            conda-forge/osx-arm64::pysocks-1.7.1-py310hbe9552e_4
#   pysoundfile        conda-forge/noarch::pysoundfile-0.10.3.post1-pyhd3deb0d_0
#   requests           conda-forge/noarch::requests-2.27.1-pyhd8ed1ab_0
#   resampy            conda-forge/noarch::resampy-0.2.2-py_0
#   scikit-learn       conda-forge/osx-arm64::scikit-learn-1.0.2-py310h5f111c3_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.1.0-pyh8a188c0_0
#   urllib3            conda-forge/noarch::urllib3-1.26.8-pyhd8ed1ab_1
#   x264               conda-forge/osx-arm64::x264-1!161.3030-h3422bc3_1
#
# The following packages will be UPDATED:
#
#   python                          3.10.1-h43b31ca_2_cpython --> 3.10.2-h70c1b39_0_cpython
#
# The following packages will be DOWNGRADED:
#
#   numpy                              1.22.0-py310h567df17_0 --> 1.21.5-py310h296e039_0
#   openssl                                  3.0.0-h3422bc3_2 --> 1.1.1l-h3422bc3_0
#
#
#
# Downloading and Extracting Packages
# idna-3.3             | 55 KB     | ##################################### | 100%
# scikit-learn-1.0.2   | 7.3 MB    | ##################################### | 100%
# brotlipy-0.7.0       | 349 KB    | ##################################### | 100%
# requests-2.27.1      | 53 KB     | ##################################### | 100%
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
# ffmpeg-4.3.2         | 46.6 MB   | ##################################### | 100%
# pysocks-1.7.1        | 28 KB     | ##################################### | 100%
# resampy-0.2.2        | 332 KB    | ##################################### | 100%
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
# pooch-1.6.0          | 44 KB     | ##################################### | 100%
# libopus-1.3.1        | 247 KB    | ##################################### | 100%
# python-3.10.2        | 12.3 MB   | ##################################### | 100%
# librosa-0.9.0        | 153 KB    | ##################################### | 100%
# audioread-2.1.9      | 34 KB     | ##################################### | 100%
# pyopenssl-22.0.0     | 49 KB     | ##################################### | 100%
# numpy-1.21.5         | 5.5 MB    | ##################################### | 100%
# llvmlite-0.38.0      | 243 KB    | ##################################### | 100%
# pysoundfile-0.10.3.p | 23 KB     | ##################################### | 100%
# nettle-3.6           | 1.2 MB    | ##################################### | 100%
# libvorbis-1.3.7      | 249 KB    | ##################################### | 100%
# lame-3.100           | 516 KB    | ##################################### | 100%
# charset-normalizer-2 | 35 KB     | ##################################### | 100%
# libflac-1.3.3        | 320 KB    | ##################################### | 100%
# x264-1!161.3030      | 2.0 MB    | ##################################### | 100%
# libllvm11-11.1.0     | 20.9 MB   | ##################################### | 100%
# libogg-1.3.4         | 203 KB    | ##################################### | 100%
# libsndfile-1.0.31    | 564 KB    | ##################################### | 100%
# urllib3-1.26.8       | 100 KB    | ##################################### | 100%
# threadpoolctl-3.1.0  | 18 KB     | ##################################### | 100%
# openh264-2.1.1       | 1.3 MB    | ##################################### | 100%
# numba-0.55.1         | 3.8 MB    | ##################################### | 100%
# cryptography-36.0.1  | 1.3 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(figsize=(20, 5))
librosa.display.waveplot(x, sr=sr)
